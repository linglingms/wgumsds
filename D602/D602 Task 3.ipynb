# %%
import pandas as pd

# Read the original CSV file
df = pd.read_csv(r"C:\Users\warre\OneDrive\T_ONTIME_REPORTING_20250514_013430_NYC\T_ONTIME_REPORTING.csv")

# Display the first few rows
print(df.head())
# Out:
#    YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  ORIGIN_AIRPORT_ID  \
# 0  2025      1             1            3              10257
# 1  2025      1             1            3              10257
# 2  2025      1             1            3              10257
# 3  2025      1             1            3              10257
# 4  2025      1             1            3              10257
#
#    ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  DEST_AIRPORT_ID  \
# 0                1025702                  30257            10397
# 1                1025702                  30257            10397
# 2                1025702                  30257            10821
# 3                1025702                  30257            10821
# 4                1025702                  30257            10821
#
#    DEST_AIRPORT_SEQ_ID  DEST_CITY_MARKET_ID  CRS_DEP_TIME  DEP_TIME  \
# 0              1039707                30397           605     602.0
# ...
